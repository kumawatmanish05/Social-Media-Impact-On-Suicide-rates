# %% [markdown]
# # Importing Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

df=pd.read_csv("/kaggle/input/impact-of-social-media-on-suicide-rates/social-media-impact-on-suicide-rates.csv")
print(df.head(15))
# Out:
#     year   sex  Suicide Rate % change since 2010  \
# 0   2010  BTSX                        100.000000
# 1   2010  FMLE                        100.000000
# 2   2010   MLE                        100.000000
# 3   2011  BTSX                         98.681894
# 4   2011  FMLE                         98.183773
# 5   2011   MLE                         98.795530
# 6   2012  BTSX                         98.595123
# 7   2012  FMLE                         97.653750
# 8   2012   MLE                         98.857511
# 9   2013  BTSX                         97.119135
# 10  2013  FMLE                         95.672700
# 11  2013   MLE                         97.517070
# 12  2014  BTSX                         95.848213
# 13  2014  FMLE                         94.606231
# 14  2014   MLE                         96.154775
#
#     Twitter user count % change since 2010  \
# 0                               100.000000
# 1                               100.000000
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   year                                     30 non-null     int64
#  1   sex                                      30 non-null     object
#  2   Suicide Rate % change since 2010         30 non-null     float64
#  3   Twitter user count % change since 2010   30 non-null     float64
#  4   Facebook user count % change since 2010  30 non-null     float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 1.3+ KB
# None

# %% [markdown]
# # Checking Null Values

# %%
print(df.isnull().sum())
# Out:
# year                                       0
# sex                                        0
# Suicide Rate % change since 2010           0
# Twitter user count % change since 2010     0
# Facebook user count % change since 2010    0
# dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
# **Line Plot Between Suicide Rate % change since 2010 and Per Year**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='year', y='Suicide Rate % change since 2010', hue='sex', marker='o')
plt.title('Suicide Rate % Change Since 2010 Over Years by Sex')
plt.show()

# %% [markdown]
# **Line Plot B/W Twitter User Count % Change Since 2010 Over Years by Sex**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='year', y='Twitter user count % change since 2010', hue='sex', marker='o')
plt.title('Twitter User Count % Change Since 2010 Over Years by Sex')
plt.show()

# %% [markdown]
# **Line Plot B/W Facebook User Count % Change Since 2010 Over Years by Sex**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='year', y='Facebook user count % change since 2010', hue='sex', marker='o')
plt.title('Facebook User Count % Change Since 2010 Over Years by Sex')
plt.show()

# %% [markdown]
# **Hist Plot B/w Suicide Rate % Change vs. Twitter User Count % Change**

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Twitter user count % change since 2010', y='Suicide Rate % change since 2010', hue='sex')
plt.title('Suicide Rate % Change vs. Twitter User Count % Change')
plt.show()

# %% [markdown]
# **Scatter Plot B/w Suicide Rate % Change vs. Twitter User Count % Change**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Twitter user count % change since 2010', y='Suicide Rate % change since 2010', hue='sex')
plt.title('Suicide Rate % Change vs. Twitter User Count % Change')
plt.show()

# %% [markdown]
# **Scatter Plot B/w Suicide Rate % Change vs. Facebook User Count % Change**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Facebook user count % change since 2010', y='Suicide Rate % change since 2010', hue='sex')
plt.title('Suicide Rate % Change vs. Facebook User Count % Change')
plt.show()

# %% [markdown]
# **Scatter Plot B/w Suicide Rate % Change vs Twitter User Count % Change**

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Twitter user count % change since 2010', y='Suicide Rate % change since 2010', hue='sex')
plt.title('Suicide Rate % Change vs. Twitter User Count % Change')
plt.show()

# %% [markdown]
# **Distribution of Suicide Rate % Change Since 2010**

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Suicide Rate % change since 2010', hue='sex', multiple='stack', kde=True)
plt.title('Distribution of Suicide Rate % Change Since 2010')
plt.show()

# %% [markdown]
# **Distribution of Facebook user count % change since 2010**

# %%
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Facebook user count % change since 2010', hue='sex', multiple='stack', kde=True)
plt.title('Distribution of Facebook user count % change since 2010')
plt.show()

# %% [markdown]
# **Distribution of Twitter user count % change since 2010**

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df ,x='Twitter user count % change since 2010', hue='sex', multiple='stack', kde=True)
plt.title('Distribution of Twitter user count % change since 2010')
plt.show()

# %% [markdown]
# **Box Plot of Suicide Rate % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='sex', y='Suicide Rate % change since 2010')
plt.title('Box Plot of Suicide Rate % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Box Plot of Twitter User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='sex', y='Twitter user count % change since 2010')
plt.title('Box Plot of Twitter User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Box Plot of Facebook User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='sex', y='Facebook user count % change since 2010')
plt.title('Box Plot of Facebook User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Pair Plot of Suicide Rate and Social Media Usage % Changes**

# %%
sns.pairplot(df, hue='sex')
plt.suptitle('Pair Plot of Suicide Rate and Social Media Usage % Changes', y=1.02)
plt.show()

# %% [markdown]
# **Violin Plot of Suicide Rate % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='sex', y='Suicide Rate % change since 2010')
plt.title('Violin Plot of Suicide Rate % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Violin Plot of Twitter User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='sex', y='Twitter user count % change since 2010')
plt.title('Violin Plot of Twitter User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Violin Plot of Facebook User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x='sex', y='Facebook user count % change since 2010')
plt.title('Violin Plot of Facebook User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Bar Plot on Average Suicide Rate % Change Since 2010 by Year**

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='year', y='Suicide Rate % change since 2010', hue='sex', ci=None)
plt.title('Average Suicide Rate % Change Since 2010 by Year')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='year', y='Twitter user count % change since 2010', hue='sex', ci=None)
plt.title('Average Twitter User Count % Change Since 2010 by Year')
plt.show()

# %% [markdown]
# **Bar Plot on Average Facebook User Count % Change Since 2010 by Year**

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df, x='year', y='Facebook user count % change since 2010', hue='sex', ci=None)
plt.title('Average Facebook User Count % Change Since 2010 by Year')
plt.show()

# %% [markdown]
# **KDE Plot of Suicide Rate % Change Since 2010**

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='Suicide Rate % change since 2010', hue='sex', fill=True)
plt.title('KDE Plot of Suicide Rate % Change Since 2010')
plt.show()

# %% [markdown]
# **KDE Plot of Twitter User Count % Change Since 2010**

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='Twitter user count % change since 2010', hue='sex', fill=True)
plt.title('KDE Plot of Twitter User Count % Change Since 2010')
plt.show()

# %% [markdown]
# **KDE Plot of Facebook User Count % Change Since 2010**

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=df, x='Facebook user count % change since 2010', hue='sex', fill=True)
plt.title('KDE Plot of Facebook User Count % Change Since 2010')
plt.show()

# %% [markdown]
# **Swarm Plot of Suicide Rate % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(data=df, x='sex', y='Suicide Rate % change since 2010')
plt.title('Swarm Plot of Suicide Rate % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Swarm Plot of Twitter User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(data=df, x='sex', y='Twitter user count % change since 2010')
plt.title('Swarm Plot of Twitter User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Swarm Plot of Facebook User Count % Change Since 2010 by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(data=df, x='sex', y='Facebook user count % change since 2010')
plt.title('Swarm Plot of Facebook User Count % Change Since 2010 by Sex')
plt.show()

# %% [markdown]
# **Count Plot of Entries by Sex**

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='sex')
plt.title('Count Plot of Entries by Sex')
plt.show()
